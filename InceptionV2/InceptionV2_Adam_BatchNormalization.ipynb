# %%
#importing required libraries
from keras.datasets import cifar100
from tensorflow import keras
import keras, os
import numpy as np
import tensorflow as tf
from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, AvgPool2D, concatenate
from keras.layers import Conv2D, MaxPool2D, BatchNormalization, Input, Softmax
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import optimizers
from keras.metrics import Precision, Recall
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras import backend as K
from keras import regularizers
from keras.optimizers import Adam

# %%
train=True
num_classes = 100
reduction_factor = 8

(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train/ 255.0
x_test = x_test/ 255.0

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %%
def InceptionA(model):
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 32, kernel_size = (3,3), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 48, kernel_size = (3,3), strides = 1, padding ='same' )(model)
  model = BatchNormalization()(model)
  # model = Dropout(0.1)(model)
  maxpool_2 = MaxPool2D(pool_size = (3,3), strides = 1, padding = 'same')(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 1, padding = 'same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)

  model = concatenate([maxpool_2, model], axis = -1)
  return model

# %%
def InceptionB(model):
  model = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,7), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (7,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,7), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (7,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,7), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (7,1), strides = 1, padding ='same'  )(model)
  model = BatchNormalization()(model)
  # model = Dropout(0.1)(model)
  # model = keras.layers.Leakyelu()(model)
  maxpool_3 = MaxPool2D(pool_size =(3,3), strides = 1, padding = 'same')(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)

  model = concatenate([maxpool_3, model], axis = -1)
  return model

# %%
def InceptionC(model):
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,3), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (3,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,3), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (3,1), strides = 1, padding ='same'  )(model)
  model = BatchNormalization()(model)
  # model = Dropout(0.1)(model)
  # model = keras.layers.Leakyelu()(model)
  maxpool_4 = MaxPool2D(pool_size =(3,3), strides = 1, padding = 'same')(model)
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)

  model = concatenate([maxpool_4, model], axis = -1)
  return model

# %%
def Inception_reduction_1(model):
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)
  maxpool_5 = MaxPool2D(3, strides = 2, padding = 'same')(model)

  model = concatenate([maxpool_5, model], axis = -1)
  return model

# %%
def Inception_reduction_2(model):
  model = Conv2D(filters = 128, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (3,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,3), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)
  maxpool_6 = MaxPool2D(3, strides = 2, padding = 'same')(model)

  model = concatenate([maxpool_6, model], axis = -1)
  return model

# %%
x_shape = keras.Input((32, 32, 3))

num_inceptionA = 2
num_inceptionB = 3
num_inceptionC = 1

model = Conv2D(filters = 32, kernel_size = (3,3), strides = 2, padding ='same'  )(x_shape)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 32, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 64, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
model = BatchNormalization()(model)
model = keras.layers.LeakyReLU()(model)
# model = Dropout(0.1)(model)
maxpool_1 = MaxPool2D(pool_size = (3,3), strides = 2)(model)

model = Conv2D(filters = 64, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 128, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
# model = BatchNormalization()(model)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 128, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
# model = Dropout(0.1)(model)
model = BatchNormalization()(model)
model = keras.layers.LeakyReLU()(model)

for i in range(num_inceptionA):
  model = InceptionA(model)

# model = Inception_reduction_1(model)

for i in range(num_inceptionB):
  model = InceptionB(model)

# model = Inception_reduction_2(model)

for i in range(num_inceptionC):
  model = InceptionC(model)

avgpool = AvgPool2D(pool_size = (1,1))(model)
# Connected Layers
flatten = Flatten()(avgpool)
dense = Dense(4096)(flatten)
dense_act = keras.layers.LeakyReLU()(dense)
# model = Dropout(0.4)(model)
dense100 = Dense(100, activation = 'softmax')(dense_act)

# Create model
model1 = keras.Model(x_shape, dense100)
model1.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   18496       conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 16, 16, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 16, 16, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   36928       leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 128)    73856       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 128)    512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 8, 8, 128)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 32)     4128        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 32)     1056        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 32)     9248        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 32)     1056        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 48)     13872       conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 48)     192         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     27712       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     4160        conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 48)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 8, 8, 64)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 112)    0           max_pooling2d_1[0][0]
#                                                                  leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 32)     3616        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 32)     1056        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 32)     9248        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 32)     1056        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 48)     13872       conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 48)     192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     27712       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     4160        conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 48)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 64)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 112)    0           max_pooling2d_2[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     7232        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    57472       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 128)    512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    16512       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 8, 128)    0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 128)    57472       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 128)    16512       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 8, 8, 128)    0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 256)    0           max_pooling2d_4[0][0]
#                                                                  leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 128)    57472       conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    16512       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 8, 8, 128)    0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 256)    0           max_pooling2d_5[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 256)    65792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 256)    65792       conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 256)    1024        conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 256)    65792       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 256)    65792       conv2d_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 512)    0           max_pooling2d_6[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 8, 8, 512)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32768)        0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4096)         134221824   flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 4096)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          409700      leaky_re_lu_8[0][0]
# ==================================================================================================
# Total params: 138,768,292
# Trainable params: 138,766,436
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %%
opt = Adam(lr=0.00001)
model1.compile(optimizer=opt,
                loss='categorical_crossentropy',
                metrics=['accuracy', 'Precision', 'Recall'])

# %%
batch_size = 128

checkpoint = ModelCheckpoint("InceptionV2_Adam_batchnormalizaton", monitor='val_accuracy', verbose=2, save_best_only=True, save_weights_only=True, mode='auto')
early = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10, verbose=2, mode='auto')


datagen = ImageDataGenerator(width_shift_range = 0.1,
                             height_shift_range = 0.1,
                             rotation_range = 10,
                             horizontal_flip = True,
                             vertical_flip = False,
                             fill_mode = 'nearest')
# datagen = ImageDataGenerator()
# datagen.fit(x_train)

# hist = model1.fit(x_train, y_train,
#                     steps_per_epoch=x_train.shape[0]//batch_size,
#                     epochs=100,
#                     validation_data=(x_test, y_test),callbacks=[checkpoint, early],verbose=2)
hist = model1.fit_generator(datagen.flow(x_train, y_train,
                                 batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0]//batch_size,
                    epochs=100,
                    validation_data=(x_test, y_test),callbacks=[checkpoint, early],verbose=2)
# Out:
# WARNING:tensorflow:From <ipython-input-13-643a87f1af6a>:24: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.25780, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 65s - loss: 3.1061 - accuracy: 0.2557 - precision: 0.5371 - recall: 0.1173 - val_loss: 3.1740 - val_accuracy: 0.2578 - val_precision: 0.5659 - val_recall: 0.1293
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.25780 to 0.26060, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 65s - loss: 2.8882 - accuracy: 0.2829 - precision: 0.6064 - recall: 0.1210 - val_loss: 3.1281 - val_accuracy: 0.2606 - val_precision: 0.5800 - val_recall: 0.1287
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.26060 to 0.27570, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 65s - loss: 2.8195 - accuracy: 0.2944 - precision: 0.6279 - recall: 0.1291 - val_loss: 3.0254 - val_accuracy: 0.2757 - val_precision: 0.6007 - val_recall: 0.1321
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.27570 to 0.27600, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 66s - loss: 2.7553 - accuracy: 0.3056 - precision: 0.6385 - recall: 0.1377 - val_loss: 3.0399 - val_accuracy: 0.2760 - val_precision: 0.5891 - val_recall: 0.1389
# Epoch 5/100
#
# Epoch 00005: val_accuracy improved from 0.27600 to 0.28690, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 66s - loss: 2.7188 - accuracy: 0.3123 - precision: 0.6449 - recall: 0.1422 - val_loss: 2.9997 - val_accuracy: 0.2869 - val_precision: 0.5907 - val_recall: 0.1469
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.28690 to 0.29020, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 66s - loss: 2.6776 - accuracy: 0.3206 - precision: 0.6471 - recall: 0.1494 - val_loss: 2.9674 - val_accuracy: 0.2902 - val_precision: 0.6138 - val_recall: 0.1462
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.29020 to 0.29490, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 66s - loss: 2.6253 - accuracy: 0.3313 - precision: 0.6583 - recall: 0.1590 - val_loss: 2.9692 - val_accuracy: 0.2949 - val_precision: 0.6086 - val_recall: 0.1555
# Epoch 8/100
#
# Epoch 00008: val_accuracy improved from 0.29490 to 0.29820, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 65s - loss: 2.5913 - accuracy: 0.3374 - precision: 0.6620 - recall: 0.1645 - val_loss: 2.9827 - val_accuracy: 0.2982 - val_precision: 0.5790 - val_recall: 0.1539
# Epoch 9/100
#
# Epoch 00009: val_accuracy did not improve from 0.29820
# 390/390 - 51s - loss: 2.5589 - accuracy: 0.3458 - precision: 0.6694 - recall: 0.1722 - val_loss: 2.9597 - val_accuracy: 0.2977 - val_precision: 0.5908 - val_recall: 0.1598
# Epoch 10/100
#
# Epoch 00010: val_accuracy did not improve from 0.29820
# 390/390 - 52s - loss: 2.5097 - accuracy: 0.3566 - precision: 0.6697 - recall: 0.1775 - val_loss: 2.9971 - val_accuracy: 0.2944 - val_precision: 0.5721 - val_recall: 0.1591
# Epoch 11/100
#
# Epoch 00011: val_accuracy did not improve from 0.29820
# 390/390 - 52s - loss: 2.4711 - accuracy: 0.3635 - precision: 0.6756 - recall: 0.1859 - val_loss: 2.9540 - val_accuracy: 0.2927 - val_precision: 0.5898 - val_recall: 0.1573
# Epoch 12/100
#
# Epoch 00012: val_accuracy improved from 0.29820 to 0.30300, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 67s - loss: 2.4337 - accuracy: 0.3704 - precision: 0.6788 - recall: 0.1929 - val_loss: 2.9715 - val_accuracy: 0.3030 - val_precision: 0.5811 - val_recall: 0.1762
# Epoch 13/100
#
# Epoch 00013: val_accuracy did not improve from 0.30300
# 390/390 - 52s - loss: 2.4063 - accuracy: 0.3770 - precision: 0.6798 - recall: 0.2001 - val_loss: 2.9652 - val_accuracy: 0.2931 - val_precision: 0.5749 - val_recall: 0.1620
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.30300 to 0.31320, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 67s - loss: 2.3521 - accuracy: 0.3895 - precision: 0.6939 - recall: 0.2098 - val_loss: 2.9351 - val_accuracy: 0.3132 - val_precision: 0.5804 - val_recall: 0.1736
# Epoch 15/100
#
# Epoch 00015: val_accuracy did not improve from 0.31320
# 390/390 - 52s - loss: 2.3146 - accuracy: 0.3954 - precision: 0.6954 - recall: 0.2163 - val_loss: 2.9501 - val_accuracy: 0.3071 - val_precision: 0.5754 - val_recall: 0.1779
# Epoch 16/100
#
# Epoch 00016: val_accuracy did not improve from 0.31320
# 390/390 - 52s - loss: 2.2758 - accuracy: 0.4012 - precision: 0.6981 - recall: 0.2222 - val_loss: 2.9288 - val_accuracy: 0.3073 - val_precision: 0.5748 - val_recall: 0.1799
# Epoch 17/100
#
# Epoch 00017: val_accuracy did not improve from 0.31320
# 390/390 - 52s - loss: 2.2456 - accuracy: 0.4072 - precision: 0.7053 - recall: 0.2290 - val_loss: 2.9507 - val_accuracy: 0.3084 - val_precision: 0.5816 - val_recall: 0.1824
# Epoch 18/100
#
# Epoch 00018: val_accuracy improved from 0.31320 to 0.31680, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 68s - loss: 2.2035 - accuracy: 0.4183 - precision: 0.7107 - recall: 0.2387 - val_loss: 2.8915 - val_accuracy: 0.3168 - val_precision: 0.5812 - val_recall: 0.1932
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.31680
# 390/390 - 52s - loss: 2.1677 - accuracy: 0.4256 - precision: 0.7209 - recall: 0.2466 - val_loss: 2.9570 - val_accuracy: 0.3151 - val_precision: 0.5573 - val_recall: 0.1925
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.31680
# 390/390 - 52s - loss: 2.1344 - accuracy: 0.4346 - precision: 0.7117 - recall: 0.2528 - val_loss: 2.9933 - val_accuracy: 0.3055 - val_precision: 0.5578 - val_recall: 0.1842
# Epoch 21/100
#
# Epoch 00021: val_accuracy improved from 0.31680 to 0.32930, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 67s - loss: 2.1041 - accuracy: 0.4405 - precision: 0.7253 - recall: 0.2609 - val_loss: 2.8822 - val_accuracy: 0.3293 - val_precision: 0.5848 - val_recall: 0.1993
# Epoch 22/100
#
# Epoch 00022: val_accuracy did not improve from 0.32930
# 390/390 - 52s - loss: 2.0605 - accuracy: 0.4480 - precision: 0.7237 - recall: 0.2683 - val_loss: 2.9658 - val_accuracy: 0.3184 - val_precision: 0.5693 - val_recall: 0.1987
# Epoch 23/100
#
# Epoch 00023: val_accuracy improved from 0.32930 to 0.33110, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 63s - loss: 2.0232 - accuracy: 0.4549 - precision: 0.7352 - recall: 0.2788 - val_loss: 2.9119 - val_accuracy: 0.3311 - val_precision: 0.5765 - val_recall: 0.2140
# Epoch 24/100
#
# Epoch 00024: val_accuracy did not improve from 0.33110
# 390/390 - 52s - loss: 2.0007 - accuracy: 0.4620 - precision: 0.7346 - recall: 0.2849 - val_loss: 2.8949 - val_accuracy: 0.3293 - val_precision: 0.5653 - val_recall: 0.2178
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.33110
# 390/390 - 53s - loss: 1.9544 - accuracy: 0.4743 - precision: 0.7402 - recall: 0.2969 - val_loss: 2.9517 - val_accuracy: 0.3234 - val_precision: 0.5519 - val_recall: 0.2169
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.33110
# 390/390 - 52s - loss: 1.9254 - accuracy: 0.4798 - precision: 0.7454 - recall: 0.3029 - val_loss: 2.9855 - val_accuracy: 0.3215 - val_precision: 0.5506 - val_recall: 0.2096
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.33110
# 390/390 - 53s - loss: 1.8931 - accuracy: 0.4853 - precision: 0.7504 - recall: 0.3106 - val_loss: 2.9513 - val_accuracy: 0.3252 - val_precision: 0.5530 - val_recall: 0.2146
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.33110
# 390/390 - 53s - loss: 1.8620 - accuracy: 0.4908 - precision: 0.7502 - recall: 0.3154 - val_loss: 3.0034 - val_accuracy: 0.3224 - val_precision: 0.5583 - val_recall: 0.2106
# Epoch 29/100
#
# Epoch 00029: val_accuracy improved from 0.33110 to 0.33160, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 67s - loss: 1.8189 - accuracy: 0.5045 - precision: 0.7583 - recall: 0.3282 - val_loss: 2.9445 - val_accuracy: 0.3316 - val_precision: 0.5516 - val_recall: 0.2214
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.33160
# 390/390 - 52s - loss: 1.7951 - accuracy: 0.5064 - precision: 0.7600 - recall: 0.3322 - val_loss: 3.1136 - val_accuracy: 0.3114 - val_precision: 0.5156 - val_recall: 0.2187
# Epoch 31/100
#
# Epoch 00031: val_accuracy improved from 0.33160 to 0.33420, saving model to InceptionV2_Adam_batchnormalizaton
# 390/390 - 67s - loss: 1.7649 - accuracy: 0.5155 - precision: 0.7629 - recall: 0.3399 - val_loss: 2.9433 - val_accuracy: 0.3342 - val_precision: 0.5606 - val_recall: 0.2309
# Epoch 00031: early stopping

# %%
model1.save_weights('InceptionV2_Adam_batchnormalization.h5')

# %%
model1.load_weights(filepath = 'InceptionV2_Adam_batchnormalization.h5')
scores = model1.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
print("Precison: %.2f%%" % (scores[2]*100))
print("Recall: %.2f%%" % (scores[3]*100))
# Out:
# Accuracy: 1.01%
# Precison: 0.00%
# Recall: 0.00%

# %%
# Plotting loss, accuracy, precision, recall
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['train','test'])
plt.title('loss')
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.legend(['train','test'])
plt.title('accuracy')
plt.figure()
plt.plot(hist.history['precision'])
plt.plot(hist.history['val_precision'])
plt.legend(['train','test'])
plt.title('precision')
plt.figure()
plt.plot(hist.history['recall'])
plt.plot(hist.history['val_recall'])
plt.legend(['train','test'])
plt.title('recall')
# Out:
# Text(0.5, 1.0, 'recall')

# %%
# Printing saved weights in numpy arrays
for layer in model1.layers: 
  print(layer.get_weights())
# Out:
# Streaming output truncated to the last 5000 lines.
#          [-0.0512927 , -0.05708075, -0.06690848, ..., -0.02906528,
#            0.06848048,  0.05574004],
#          [-0.07413317,  0.04699623, -0.01275536, ..., -0.01451077,
#            0.07887708, -0.06547686],
#          [ 0.00371766, -0.02655593, -0.03828395, ...,  0.05072366,
#            0.00808408,  0.04591144]]]], dtype=float32), array([ 1.16946365e-04,  1.38446660e-04,  2.42457492e-04, -2.10547987e-05,
#         3.55013690e-05,  4.78423426e-05,  5.32196391e-05,  2.13447402e-05,
#        -1.20167460e-04, -4.99971122e-07, -1.62723809e-04,  1.07815707e-04,
#         8.50870056e-05, -1.07041094e-04, -2.80916865e-04, -1.13822840e-04,
#         8.27284966e-05,  6.69205765e-05,  3.03016659e-05, -1.11526533e-04,
#        -1.06940628e-04,  5.17509143e-05,  2.49364912e-05, -1.81543597e-04,
#        -6.33719173e-06, -3.76771604e-05,  3.18156439e-04, -2.75475145e-06,
#         3.95616335e-05, -1.57288785e-04, -9.71760819e-05,  5.07536533e-05,
#        -3.07692710e-04,  2.93035846e-05, -2.06422206e-04,  1.20252618e-04,
#        -1.35703289e-04, -2.50534125e-04, -2.06933342e-04, -8.09485573e-05,
#        -6.38431520e-05, -2.36424021e-04, -1.88764170e-06, -2.67662021e-04,
#         3.25492983e-05,  9.10497838e-05, -1.46324950e-04, -8.57176128e-05],
#       dtype=float32)]
# [array([0.9999272 , 0.9995538 , 1.0002519 , 0.9997329 , 1.0004672 ,
#        0.9989619 , 0.99938196, 1.0010763 , 1.0007114 , 1.0023494 ,
#        1.0014817 , 1.001374  , 1.0000373 , 1.0003387 , 0.9983196 ,
#        0.9990059 , 0.99983925, 0.99958706, 1.0020758 , 0.9995201 ,
#        0.9989499 , 1.0001298 , 0.9999754 , 1.0022336 , 1.0012246 ,
#        1.0005958 , 0.9985191 , 1.0000385 , 0.9979855 , 0.9976657 ,
#        0.99899095, 1.0029119 , 0.99963504, 0.9985197 , 0.9986247 ,
#       dtype=float32)]
# [array([[[[-0.01349062,  0.17747483, -0.12482314, ...,  0.25758514,
#           -0.1843687 ,  0.21105897],
#          [ 0.17162368, -0.17621063, -0.2510906 , ...,  0.28852612,
#           -0.22709523,  0.18884002],
#          [ 0.23677203,  0.05274519,  0.29273185, ..., -0.2886904 ,
#           -0.21774492, -0.27156857],
#          ...,
#          [-0.19348936, -0.26061058,  0.13448559, ..., -0.16964376,
#           -0.07037241,  0.02830781],
#          [ 0.0562493 ,  0.08826172,  0.21752375, ...,  0.18624039,
#            0.28089154,  0.0826508 ],
#          [ 0.24305488,  0.09937813,  0.26530305, ..., -0.02495993,
#           -0.16202816, -0.2096744 ]]]], dtype=float32), array([ 1.0042572e-03,  3.2417025e-04,  6.0176715e-04, -5.8367738e-04,
#        -2.2534111e-04, -3.1313606e-04, -8.3822676e-04,  2.9803425e-04,
#         1.0192614e-03,  1.9676640e-06, -3.6128808e-04,  3.8540424e-05,
#        -4.4227517e-04,  1.0669626e-03, -6.1680871e-04,  8.9014549e-04,
#         5.6043389e-04,  9.4971532e-04, -1.3561654e-03,  6.6603173e-04,
#         5.3077715e-04, -8.1218348e-04,  2.4524209e-04,  1.9788722e-04,
#         7.0089789e-04, -8.0395461e-04, -3.3415260e-04, -8.2317230e-05,
#        -3.9129541e-04, -1.6773412e-04,  5.7367986e-04,  9.6053939e-04],
#       dtype=float32)]
# [array([[[[ 0.07060439, -0.00237052,  0.02755111, ..., -0.0527028 ,
#           -0.03682958, -0.04244053],
#          [-0.04263755,  0.10030662,  0.09120542, ...,  0.06456431,
#           -0.07162479,  0.0203658 ],
#          [-0.06655765,  0.0313548 ,  0.09328058, ..., -0.07055641,
#            0.05504825,  0.00519281],
#          ...,
#          [-0.06328525, -0.07838241, -0.01160692, ..., -0.03194526,
#            0.00086128,  0.01914233],
#          [ 0.08877935, -0.05332033, -0.01291313, ..., -0.00702251,
#           -0.02803984,  0.01878458],
#          [ 0.02297432, -0.04162453,  0.09934118, ...,  0.02786074,
#            0.08709691,  0.06853185]],
#
#         [[ 0.04788479,  0.01919533, -0.10021907, ..., -0.0281926 ,
#           -0.02817623,  0.00579991],
#          [ 0.09664687,  0.00017202,  0.04763151, ...,  0.03517983,
#           -0.08381806,  0.09515266],
#          [-0.01157614,  0.07800657, -0.05896697, ..., -0.03198879,
#            0.02293276, -0.00219742],
#          ...,
#          [ 0.00413638,  0.0765634 , -0.02010066, ..., -0.01338131,
#            0.00178859,  0.03315261],
#          [-0.00584336,  0.00172688, -0.05440992, ..., -0.0566898 ,
#           -0.01574834, -0.06406283],
#          [-0.02239644, -0.0862143 , -0.10117544, ...,  0.03592677,
#            0.00085818, -0.04380788]],
#
#         [[ 0.05296733,  0.04116607,  0.04115986, ...,  0.03423532,
#           -0.0407066 , -0.02715094],
#          [ 0.06495308, -0.02538203, -0.0337242 , ...,  0.00633332,
#            0.02994844, -0.04155608],
#          [-0.02137623,  0.08337516, -0.05922155, ..., -0.09404397,
#           -0.06201466, -0.04142183],
#          ...,
#          [ 0.09968341, -0.09039717, -0.04861281, ..., -0.07044742,
#           -0.06303984, -0.09412115],
#          [ 0.00605058,  0.08529294, -0.07128109, ...,  0.07126413,
#           -0.03392169, -0.09596359],
#          [ 0.04404901,  0.04256089, -0.09899477, ..., -0.03123691,
#           -0.09596431,  0.0731785 ]]],
#
#
#        [[[-0.02522208,  0.01609751, -0.06217172, ..., -0.07752902,
#            0.05231416,  0.02653972],
#          [ 0.0693232 , -0.08160881, -0.05449459, ..., -0.05249647,
#           -0.07117533, -0.0947179 ],
#          [-0.02703459, -0.07504348,  0.02833292, ...,  0.0089954 ,
#           -0.02625023, -0.0507504 ],
#          ...,
#          [-0.03017325, -0.01331199,  0.06313055, ...,  0.00835096,
#            0.06091037,  0.00059476],
#          [ 0.05500222,  0.0968064 , -0.05815447, ..., -0.0440127 ,
#           -0.08387367, -0.02762767],
#          [ 0.03437498, -0.01588458,  0.01056093, ...,  0.0306282 ,
#           -0.00946067, -0.10302313]],
#
#         [[ 0.08246137, -0.06816759, -0.10154688, ..., -0.07670587,
#           -0.10195541, -0.06747413],
#          [-0.0601248 ,  0.03854281,  0.04319958, ..., -0.03629131,
#            0.03160924,  0.08214604],
#          [ 0.01622011,  0.05515559,  0.09360915, ...,  0.03681225,
#           -0.08752245,  0.0083161 ],
#          ...,
#          [ 0.06157942,  0.07768612,  0.02724432, ...,  0.02152355,
#           -0.05718242, -0.01155062],
#          [ 0.10033776,  0.00505665, -0.03563739, ...,  0.06978274,
#            0.05992001, -0.09594459],
#          [ 0.0671928 ,  0.07309166, -0.0167734 , ..., -0.09059782,
#            0.05792418, -0.00156387]],
#
#         [[-0.01093687, -0.00264547, -0.01993225, ...,  0.0803718 ,
#            0.05392182,  0.00256677],
#          [ 0.01962304, -0.06016641,  0.00199676, ..., -0.00558792,
#            0.08873869,  0.08101255],
#          [-0.03527594, -0.06919958,  0.04268226, ...,  0.00060961,
#           -0.00847741,  0.02467961],
#          ...,
#          [-0.04517956,  0.07237936, -0.07632361, ...,  0.04415876,
#           -0.04552884,  0.04465466],
#          [-0.1004248 ,  0.00283071, -0.09445854, ..., -0.06964504,
#           -0.07672363,  0.03590342],
#          [ 0.00898217,  0.00334341,  0.02407983, ...,  0.05657825,
#            0.04853456, -0.08580064]]],
#
#
#        [[[-0.07251847,  0.04910015,  0.00316675, ...,  0.06051876,
#            0.03620473,  0.03357998],
#          [ 0.02460528, -0.07094773, -0.00382325, ...,  0.08359686,
#           -0.05702549, -0.09725858],
#          [ 0.00567659, -0.03073864, -0.08991909, ...,  0.09814047,
#           -0.03218534,  0.0202524 ],
#          ...,
#          [ 0.0506153 ,  0.07075779,  0.06920393, ..., -0.08558712,
#            0.00625662, -0.0657915 ],
#          [ 0.00517486,  0.01307599, -0.00608778, ...,  0.00592891,
#           -0.07307474, -0.07461295],
#          [-0.01278555,  0.03884709,  0.06314684, ...,  0.0797574 ,
#           -0.01830455, -0.09293194]],
#
#         [[ 0.09925334, -0.00541754, -0.03087619, ..., -0.06035623,
#            0.04104113,  0.03966688],
#          [ 0.06991313, -0.00283986, -0.02916752, ...,  0.01486386,
#            0.07795051, -0.10177815],
#          [ 0.00425686, -0.04894698,  0.09429926, ...,  0.07024843,
#           -0.08675554,  0.07084424],
#          ...,
#          [ 0.05873315,  0.02945662, -0.06958107, ..., -0.08345207,
#           -0.09022788,  0.09251035],
#          [ 0.07660568, -0.06821737,  0.01797187, ...,  0.05198793,
#           -0.07808128, -0.05793715],
#          [-0.08806623,  0.04819041, -0.07873119, ..., -0.00125165,
#            0.04608425, -0.00816516]],
#
#         [[ 0.02677093, -0.07046027,  0.00889125, ...,  0.03882665,
#            0.06745512,  0.09124865],
#          [ 0.05682362, -0.03530835,  0.02278303, ..., -0.09441468,
#           -0.08348152,  0.08056664],
#          [ 0.04407218, -0.00415682,  0.08527988, ...,  0.0622719 ,
#           -0.08152342,  0.019813  ],
#          ...,
#          [-0.10086998, -0.02354373,  0.07100836, ...,  0.01407369,
#           -0.08952724, -0.0876173 ],
#          [ 0.09650908, -0.01015804, -0.10097309, ..., -0.02663916,
#            0.0685082 ,  0.09738985],
#          [ 0.04730367, -0.09827046,  0.09026948, ...,  0.05167402,
#            0.07471663,  0.09278426]]]], dtype=float32), array([ 6.4801547e-04,  5.7809324e-05,  4.3966178e-05, -4.1168203e-04,
#        -1.1801489e-03, -1.2191060e-03, -5.1874970e-04, -4.4328542e-04,
#         4.7792597e-05, -2.9850545e-04, -3.3919900e-04, -6.3581439e-04,
#         4.1982855e-04, -2.7885329e-04,  2.4283830e-04, -8.2492607e-04,
#         2.6344153e-04,  3.7149008e-04,  2.1770436e-04, -4.1570800e-04,
#         1.5462843e-03, -3.0353161e-05, -4.9070659e-04,  6.3343672e-04,
#         1.2556125e-03,  1.9073213e-04,  1.9873292e-04, -7.3358021e-04,
#        -1.2399536e-03,  3.2347947e-04, -6.0323230e-04, -7.9394347e-04],
#       dtype=float32)]
# [array([[[[ 0.24046491, -0.2725046 , -0.11438799, ...,  0.03217579,
#            0.11476252,  0.18696907],
#          [-0.00431704,  0.08368757,  0.25927168, ..., -0.28533414,
#           -0.13107936,  0.14057642],
#          [ 0.0065923 , -0.03375223,  0.0527001 , ..., -0.07352877,
#            0.00709393,  0.24575593],
#          ...,
#          [-0.07550193,  0.0551256 , -0.06764644, ..., -0.3062956 ,
#           -0.17093673,  0.06721874],
#          [ 0.03437657,  0.14019077, -0.26840696, ...,  0.1556986 ,
#           -0.19546501,  0.22883376],
#          [-0.07483923,  0.00076997, -0.16481295, ...,  0.21508388,
#           -0.02153246, -0.25849855]]]], dtype=float32), array([ 4.4498060e-04, -2.7902558e-04,  8.8226877e-04,  1.2469948e-04,
#         6.8903208e-04, -5.1293526e-05,  7.8204175e-04,  4.5997978e-05,
#         4.5113772e-04,  1.9084571e-04,  5.4103491e-04, -1.1591455e-03,
#        -2.6035940e-04, -5.5645418e-04,  7.4680179e-04,  1.7730451e-04,
#         1.2937111e-03, -8.5704005e-04, -3.2737927e-04,  7.8057457e-04,
#         7.4197171e-04, -5.1405415e-04,  5.7373200e-06, -7.8135385e-04,
#         9.8842010e-04, -7.7400164e-04,  1.5344644e-03, -4.6989942e-04,
#        -7.8171660e-04, -1.3581490e-03, -2.9191413e-04,  7.4009289e-04],
#       dtype=float32)]
# [array([[[[ 0.01788632, -0.04617604, -0.04887313, ..., -0.08709404,
#           -0.08884868,  0.05687225],
#          [ 0.01307169, -0.05744288,  0.03485087, ...,  0.05702502,
#           -0.02576964, -0.05276516],
#          [-0.08882814, -0.03738971,  0.06619089, ...,  0.01449838,
#            0.02962996,  0.03173882],
#          ...,
#          [-0.05322983,  0.05300131,  0.06183684, ..., -0.05047464,
#            0.00444223, -0.07255703],
#          [ 0.02565675, -0.06547073,  0.06003609, ...,  0.0045653 ,
#            0.02927922, -0.09089659],
#          [-0.08623645, -0.07542828,  0.07471813, ..., -0.01855588,
#           -0.00888414,  0.04784709]],
#
#         [[ 0.05647973,  0.06680302, -0.00793807, ...,  0.04128508,
#            0.04852211,  0.00651507],
#          [-0.04364899,  0.01018456, -0.07426406, ...,  0.00411782,
#           -0.04750274, -0.0599129 ],
#          [ 0.05893129, -0.05535399,  0.04616974, ..., -0.04082317,
#           -0.00909789,  0.0868572 ],
#          ...,
#          [ 0.00271439, -0.03798389, -0.08935489, ..., -0.07319994,
#           -0.07694008,  0.0807737 ],
#          [ 0.05006204,  0.01677031,  0.07462189, ...,  0.04220502,
#           -0.0755619 , -0.01209723],
#          [-0.04496475,  0.0099469 , -0.07873831, ...,  0.00173407,
#            0.07093114, -0.06881013]],
#
#         [[-0.08535199,  0.08987207, -0.0578039 , ..., -0.08879781,
#           -0.07937849, -0.08193497],
#          [ 0.07018784, -0.00994711,  0.0299247 , ...,  0.0363687 ,
#            0.06770089, -0.03921162],
#          [-0.06605296,  0.02350964, -0.03711145, ...,  0.08612607,
#            0.07633563, -0.08292519],
#          ...,
#          [-0.07394379, -0.04537042,  0.08358247, ..., -0.07842171,
#           -0.07362499,  0.04906201],
#          [-0.04379245, -0.03031465,  0.0153971 , ..., -0.08075825,
#           -0.07520093, -0.07273437],
#          [-0.08120083,  0.08780669,  0.06126983, ..., -0.08188424,
#            0.07912955, -0.05642384]]],
#
#
#        [[[-0.03835175,  0.01337498, -0.00829844, ...,  0.0367343 ,
#           -0.05879318,  0.00405521],
#          [ 0.07771726,  0.0810126 , -0.07461692, ...,  0.08892426,
#           -0.02518487, -0.06649697],
#          [-0.08001485, -0.08268944,  0.04405457, ..., -0.07873414,
#            0.07919566, -0.01803164],
#          ...,
#          [ 0.0417156 , -0.01337097,  0.07503915, ..., -0.0079471 ,
#            0.01580244,  0.07349507],
#          [ 0.07565581, -0.03773576, -0.00855741, ..., -0.02724431,
#           -0.03606583, -0.03720876],
#          [-0.0310821 ,  0.05145364, -0.03343989, ..., -0.02815964,
#            0.05118487, -0.02473508]],
#
#         [[-0.00761118, -0.01562801,  0.06751487, ...,  0.0039831 ,
#            0.07307564,  0.08693205],
#          [ 0.0308571 , -0.07241527,  0.06884125, ..., -0.02350338,
#            0.01870191, -0.00204339],
#          [ 0.05632339, -0.05876153,  0.08267807, ...,  0.03494949,
#           -0.02822726, -0.08572109],
#          ...,
#          [-0.07084148, -0.0491292 ,  0.01159666, ...,  0.02952827,
#           -0.01691721,  0.0220108 ],
#          [ 0.03726719, -0.04683866,  0.06939696, ...,  0.06467623,
#            0.08644754,  0.00198065],
#          [ 0.01349571,  0.00466001,  0.05589261, ..., -0.01400215,
#           -0.00718636,  0.05432165]],
#
#         [[-0.06077123,  0.07430019, -0.08875453, ..., -0.01790108,
#            0.01525675,  0.02086393],
#          [-0.00217253, -0.05725481, -0.07585081, ...,  0.02594051,
#            0.00763187,  0.05122793],
#          [ 0.01426724, -0.04897519,  0.07612055, ...,  0.08986322,
#           -0.04849061, -0.05127807],
#          ...,
#          [ 0.07914424,  0.00517536, -0.06511044, ..., -0.02684517,
#            0.07003382,  0.05380129],
#          [-0.08890506, -0.0273119 , -0.0878556 , ..., -0.01222638,
#            0.01376858, -0.02823867],
#          [ 0.02251704,  0.03483782,  0.02187314, ..., -0.08673026,
#            0.07103158, -0.03522581]]],
#
#
#        [[[-0.05594253,  0.01113701, -0.08310249, ..., -0.06457833,
#            0.07704589, -0.06701751],
#          [ 0.00418807, -0.01779293,  0.04439447, ...,  0.0427509 ,
#            0.043508  ,  0.04396141],
#          [-0.05635078,  0.07296234,  0.03121081, ...,  0.07850161,
#            0.08421084, -0.07983543],
#          ...,
#          [-0.00295476,  0.07811412, -0.07990353, ...,  0.08265516,
#            0.07941575,  0.07873331],
#          [-0.00681238,  0.04892089, -0.02560717, ..., -0.06256659,
#            0.06478307, -0.08899173],
#          [-0.05193884,  0.00240401, -0.07624237, ...,  0.00419528,
#           -0.03132931,  0.0514043 ]],
#
#         [[-0.01417159, -0.00143667, -0.08881649, ..., -0.05442001,
#           -0.02793812,  0.06132049],
#          [ 0.0912668 ,  0.05338109,  0.0692746 , ...,  0.00849424,
#           -0.08787744,  0.04300195],
#          [ 0.05267533, -0.03364817, -0.08458512, ..., -0.01227675,
#           -0.05987818,  0.08117472],
#          ...,
#          [ 0.07893454,  0.05248488, -0.00422883, ...,  0.06622796,
#           -0.04533957,  0.07801955],
#          [-0.03706308, -0.0478262 , -0.03979157, ...,  0.01953192,
#            0.07724042,  0.04996934],
#          [-0.04734196, -0.01771663, -0.02766767, ...,  0.08016986,
#            0.05075445,  0.07955625]],
#
#         [[ 0.03001574,  0.086099  ,  0.00321928, ...,  0.03399003,
#           -0.08346152, -0.0618708 ],
#          [-0.06933057,  0.03738274,  0.07192206, ..., -0.07613306,
#           -0.07518794,  0.05020692],
#          [ 0.06279773,  0.04633187, -0.02131469, ...,  0.04824347,
#            0.06638239, -0.09138215],
#          ...,
#          [-0.02933395,  0.05402175, -0.03592359, ...,  0.08727446,
#           -0.05624774,  0.06643862],
#          [-0.02921788, -0.08711996,  0.03828279, ..., -0.00438936,
#            0.06408369,  0.04741505],
#          [-0.05193895,  0.06947012, -0.08250554, ...,  0.06133164,
#            0.02065497, -0.01347333]]]], dtype=float32), array([ 6.15046738e-05, -7.87362515e-05,  6.36444893e-05, -2.01269519e-04,
#         0.1956363 , -0.33257106,  0.272228  , -1.1013452 ,  0.60963047,
#         0.7920697 ,  0.07049792, -0.6962231 ,  0.44028986,  0.8974455 ,
#         0.27196088,  0.46002695,  0.27842766, -0.23099515,  0.17488602,
#        -0.08615113,  0.4196409 ,  0.11608521, -0.31713483,  0.19032314,
#        -0.15116492,  0.26361737, -0.38130045,  0.50158304, -0.4355482 ,
#         0.9301748 ,  0.0343466 , -0.3688671 , -0.7124569 , -1.3935074 ,
#        -0.12650248,  0.6905368 ,  0.0720063 ], dtype=float32), array([0.37705716, 0.7273402 , 0.49472523, 0.68047994, 0.5354226 ,
#        0.6701322 , 0.63662976, 0.3406467 , 1.0324825 , 0.9492974 ,
#        0.5679402 , 1.0293744 , 0.72716624, 0.5646561 , 0.6204526 ,
#        0.5312734 , 0.6365527 , 0.8129203 , 1.0278382 , 0.6526929 ,
#        0.5205977 , 0.53464574, 0.48680598, 0.8531624 , 0.6616042 ,
#        0.45665303, 0.4928952 , 0.38768885, 0.899873  , 0.59715295,
#        0.7287178 , 0.39981127, 0.53943235, 0.33534822, 0.7956974 ,
#        0.4604554 , 0.56048185, 0.5001466 , 0.42925528, 0.44868097,
#        0.67537874, 0.3910009 , 0.81887543, 0.47561005, 0.7951519 ,
#        0.66365474, 0.62067235, 1.0592597 ], dtype=float32)]
# [array([[[[-0.04604479,  0.01069726,  0.01152475, ..., -0.06758517,
#            0.02168217,  0.00574417],
#          [ 0.04914707,  0.07017472, -0.02415245, ...,  0.05522302,
#            0.03508814,  0.02823211],
#          [-0.07553783, -0.01889675, -0.01701002, ..., -0.05674518,
#            0.04456891,  0.01487937],
#          ...,
#          [-0.05408511, -0.03540213, -0.00217519, ..., -0.03991568,
#            0.00251977, -0.00538516],
#          [ 0.0647508 , -0.03789048,  0.00964043, ..., -0.03742678,
#           -0.06067951, -0.07110696],
#          [ 0.00549632,  0.04454402,  0.0538064 , ...,  0.05464182,
#            0.02593051,  0.0406783 ]],
#
#         [[ 0.00267141,  0.01802619, -0.01689287, ...,  0.07778413,
#           -0.07174031, -0.0597271 ],
#          [ 0.00532781, -0.05350407, -0.04448257, ...,  0.02214942,
#            0.05882696,  0.03060246],
#          [-0.01399388,  0.01121081, -0.07587624, ..., -0.06500859,
#            0.00380083, -0.01495563],
#          ...,
#          [-0.05706025,  0.00662187,  0.00995635, ...,  0.00205575,
#            0.01363667, -0.06925038],
#          [ 0.03838399, -0.02840303, -0.07491606, ..., -0.04296793,
#           -0.04937083,  0.03882667],
#          [ 0.05226436, -0.07450186, -0.06746014, ...,  0.00766288,
#           -0.00559957, -0.06256621]],
#
#         [[ 0.00106326, -0.00824666,  0.00987673, ...,  0.01127303,
#            0.02753812,  0.01852944],
#          [-0.0022121 , -0.03381402, -0.03774386, ...,  0.07189161,
#           -0.02651842,  0.03080074],
#          [ 0.05063707, -0.04001904, -0.05670072, ...,  0.0359819 ,
#           -0.01536722, -0.02517831],
#          ...,
#          [ 0.0400107 , -0.03873315, -0.02869065, ..., -0.05681332,
#           -0.04692637,  0.02634988],
#          [ 0.0719805 ,  0.06113774,  0.0027837 , ..., -0.06686086,
#            0.05350187, -0.03381208],
#          [ 0.00121481,  0.05782027, -0.06156067, ...,  0.06626808,
#           -0.00454741,  0.00147033]]],
#
#
#        [[[ 0.03115038,  0.05011114, -0.01907376, ..., -0.07134317,
#            0.07310502,  0.01740714],
#          [ 0.04164337, -0.04360987, -0.00104396, ..., -0.04320007,
#           -0.04437383,  0.03719223],
#          [-0.03193647,  0.04604311, -0.05964564, ...,  0.01246545,
#            0.00978084, -0.06850026],
#          ...,
#          [ 0.02765653,  0.02791284,  0.00869981, ..., -0.04231919,
#           -0.05640119, -0.01408532],
#          [-0.05830545, -0.0167813 , -0.00714294, ..., -0.05665426,
#           -0.04739227,  0.0520141 ],
#          [ 0.03229316,  0.01865962,  0.06521168, ...,  0.05015843,
#            0.04995142, -0.01330419]],
#
#         [[ 0.04696983,  0.03235317, -0.0323891 , ..., -0.05973773,
#           -0.06257607, -0.0133113 ],
#          [-0.00428469, -0.04200818,  0.06334426, ...,  0.03834195,
#           -0.03127591, -0.05030993],
#          [-0.01660924,  0.03396807,  0.00038421, ...,  0.07864248,
#            0.00477359, -0.06975035],
#          ...,
#          [ 0.06542417,  0.03614979, -0.06893545, ..., -0.04211331,
#            0.02317007,  0.04968102],
#          [-0.02317242, -0.06340018,  0.06451306, ..., -0.05093338,
#            0.02200441, -0.02349483],
#          [ 0.01852185, -0.00813251,  0.0072259 , ...,  0.00428317,
#            0.0041775 ,  0.05865358]],
#
#         [[ 0.05792727,  0.03173428, -0.01519292, ...,  0.03095104,
#           -0.06716933, -0.04222684],
#          [-0.04370326, -0.02463849,  0.06391433, ...,  0.07577031,
#           -0.02142429,  0.05904886],
#          [ 0.01883104,  0.03048395,  0.00733352, ...,  0.05411409,
#            0.01109035,  0.02791725],
#          ...,
#          [ 0.0036285 ,  0.06250612,  0.03097013, ...,  0.05918868,
#            0.01096233, -0.01420239],
#          [ 0.05888633,  0.04604603, -0.028011  , ...,  0.00209277,
#            0.0410953 , -0.03133088],
#          [-0.04427279,  0.04560389, -0.03186153, ..., -0.0239451 ,
#            0.00947066,  0.01382078]]],
#
#
#        [[[ 0.02200977,  0.05498476,  0.07561865, ...,  0.02663558,
#           -0.05944907, -0.04444041],
#          [ 0.03884736, -0.06270152, -0.07070787, ...,  0.04710415,
#            0.05498654,  0.02731972],
#          [ 0.06543437, -0.04385521,  0.03180536, ..., -0.01346791,
#            0.05005237, -0.0234065 ],
#          ...,
#          [-0.03136146, -0.04669034, -0.06981201, ...,  0.07575695,
#            0.00661771,  0.04335028],
#          [-0.0301149 , -0.04009384, -0.03295143, ..., -0.04078797,
#            0.01661729, -0.0175422 ],
#          [-0.03485072,  0.06671263,  0.04415878, ..., -0.03208411,
#           -0.01530622,  0.01074542]],
#
#         [[ 0.02154415, -0.04225714,  0.06280535, ...,  0.04403698,
#            0.07581966, -0.00904861],
#          [-0.05993327,  0.00365383,  0.05640919, ..., -0.04575147,
#           -0.04601368,  0.03595966],
#          [-0.00568717,  0.0559231 ,  0.00139652, ..., -0.06202707,
#           -0.0046902 , -0.01089775],
#          ...,
#          [-0.03995574, -0.0759857 ,  0.06062168, ..., -0.00231342,
#           -0.01840721, -0.04656721],
#          [ 0.00181581, -0.0029173 , -0.0021806 , ...,  0.01366368,
#            0.03585734,  0.04049297],
#          [ 0.06710036, -0.06029873,  0.00136925, ...,  0.02344472,
#           -0.05966382, -0.07381701]],
#
#         [[ 0.00227056, -0.06730846,  0.02180643, ...,  0.00154031,
#            0.07408316, -0.04315325],
#          [ 0.07466853, -0.07080299, -0.00716957, ...,  0.03155988,
#            0.07577066, -0.00457342],
#          [-0.0645717 ,  0.07355481,  0.05630609, ...,  0.04589562,
#           -0.05775124,  0.02560902],
#          ...,
#          [ 0.04008038, -0.06731652,  0.05773827, ..., -0.0380898 ,
#           -0.05320184,  0.01951558],
#          [-0.02168322, -0.01062241,  0.03682527, ..., -0.04169369,
#            0.00251914, -0.03406664],
#          [ 0.00154898,  0.0009679 , -0.01001863, ..., -0.02143979,
#            0.06270622, -0.04144309]]]], dtype=float32), array([ 1.4809314e-03,  8.1041991e-04, -1.4694066e-04,  1.3984765e-03,
#        -1.6415645e-03, -1.7083817e-03,  6.2546931e-04,  1.1433591e-03,
#         1.5111662e-04,  9.7064587e-04, -7.9017523e-04,  6.0243172e-05,
#         1.4474120e-03,  2.4935516e-04,  4.7812046e-04,  1.0201973e-04,
#         9.2631916e-04,  1.3501053e-04,  1.9371617e-03,  3.7155018e-04,
#         5.1661790e-04,  3.1536713e-03,  6.6025363e-04,  6.0054084e-04,
#         1.1701803e-03,  1.7328111e-04, -4.4848947e-04, -1.0875178e-03,
#        -9.8969147e-04,  9.7941527e-05, -3.9079769e-05,  1.2312416e-04,
#         7.5765391e-04, -4.2532623e-04,  2.5176423e-04, -1.0856705e-03,
#        -1.8731026e-03,  9.0460962e-04,  1.2758013e-03,  1.3034214e-03,
#        -2.3415680e-03,  7.8296446e-04,  9.7221253e-04, -1.3731351e-03,
#         2.9549337e-04, -6.3733850e-04, -5.7751121e-04,  2.9256384e-04,
#        -2.6448453e-03, -2.5036836e-03,  3.0862640e-03, -1.2348904e-05,
#         1.7153248e-03, -1.8103396e-03, -1.5414031e-03, -1.7632556e-03,
#        -3.5714646e-04, -1.6911902e-03, -2.4086228e-03, -6.5959041e-04,
#         7.7525649e-04, -1.3115349e-03, -1.9184918e-03, -4.1414009e-04],
#       dtype=float32)]
# [array([[[[ 0.04498972, -0.19244403, -0.20730124, ..., -0.01923412,
#            0.03932648, -0.14252444],
#          [-0.10473526,  0.02380765,  0.09595195, ...,  0.03332453,
#            0.18924484,  0.02911425],
#          [-0.11583205,  0.05559776,  0.1458929 , ..., -0.1669638 ,
#           -0.0805209 , -0.00293787],
#          ...,
#          [ 0.06270546, -0.12100749, -0.2053581 , ..., -0.1580599 ,
#            0.08466537, -0.05979057],
#          [-0.12332255,  0.19774833,  0.12404382, ..., -0.1727354 ,
#            0.04757586, -0.00612634],
#          [-0.21449485,  0.09973741,  0.00397199, ..., -0.13225006,
#            0.19947179, -0.16481492]]]], dtype=float32), array([ 2.19059619e-03,  1.87222532e-03,  1.31170294e-04,  2.09755660e-03,
#         8.59758758e-04,  2.31836515e-04,  1.17153395e-03,  2.40690610e-03,
#        -1.24827493e-04,  1.84950908e-03,  9.32966999e-04,  1.06263836e-03,
#         1.49480067e-03,  2.50474375e-04,  2.11815583e-03,  1.33352049e-04,
#         2.88809446e-04,  2.96776823e-04,  8.33161466e-04,  7.19501229e-04,
#         1.17616626e-04,  1.08904042e-03,  3.94515519e-04,  2.57166772e-04,
#        -1.32963283e-03, -9.95191978e-04, -3.54068034e-04,  2.00416637e-03,
#         2.09581945e-03,  8.59284366e-04,  1.85102888e-03,  1.50779064e-03,
#         1.50205378e-05,  1.46005512e-03, -1.74981513e-04,  2.20429758e-03,
#         6.79737306e-04,  5.86389215e-04,  6.33885793e-04, -8.18954722e-04,
#        -5.27787139e-04, -1.17341231e-03, -1.23666832e-03, -7.67826336e-04,
#         1.01174321e-03,  1.42132607e-03,  6.99590426e-04,  5.76160499e-04,
#         2.01167329e-03,  2.01002439e-03,  4.29880369e-04,  1.13305810e-03,
#         2.09658319e-04, -1.03478669e-03,  1.11190064e-04,  1.84645434e-03,
#         3.16979550e-03, -1.16227963e-03,  6.66117761e-04, -9.29659698e-04,
#         1.58623862e-03,  9.25736036e-04,  1.28712942e-04,  6.23574597e-04],
#       dtype=float32)]
# []
# []
# []
# [array([[[[ 0.16618213, -0.15934525, -0.06491044, ...,  0.01763414,
#            0.11328761,  0.00860736],
#          [ 0.15824816, -0.00111904,  0.03420879, ..., -0.15323132,
#            0.03987302,  0.07098265],
#          [ 0.15456446,  0.11135391,  0.07161862, ..., -0.07242712,
#           -0.07871485,  0.01308692],
#          ...,
#          [ 0.12271826, -0.17014232, -0.08745079, ...,  0.04813514,
#           -0.02925261,  0.12612966],
#          [ 0.1457842 , -0.15554373, -0.14311136, ...,  0.02398749,
#            0.04218282,  0.03958753],
#          [ 0.15864365, -0.17198576, -0.10182083, ..., -0.14610453,
#           -0.13988553,  0.05973317]]]], dtype=float32), array([ 4.78953269e-04,  2.05485127e-03,  8.97046702e-04,  4.11665824e-04,
#        -2.41626913e-04, -4.62595417e-05, -5.80738939e-04,  6.16444158e-04,
#         2.08693513e-04,  3.32693540e-04,  8.71014636e-05, -1.21060386e-03,
#         1.19191001e-03,  6.71231654e-04, -6.29178074e-04,  1.07474555e-03,
#        -1.30914035e-03, -2.01314469e-04,  3.25762405e-04,  3.47627967e-04,
#         6.15344848e-04,  3.45959706e-04, -6.60015576e-06,  6.05000125e-04,
#        -1.68064798e-04, -8.58450716e-04, -5.19844412e-04,  7.89981917e-04,
#         4.44959122e-04, -9.06012836e-04, -1.46029214e-03, -2.52989819e-04,
#         3.28657916e-04, -7.08322099e-04,  5.58992906e-04,  2.04270764e-04,
#        -1.03555608e-03, -1.71207613e-03, -3.35657503e-04,  5.31880301e-04,
#        -2.23084213e-03, -1.06631801e-03,  8.42556983e-05,  1.55188469e-03,
#        -4.37521048e-05,  4.74259083e-04,  2.49285891e-04, -9.14555741e-04,
#        -2.15759879e-04,  7.85587472e-04, -9.38882993e-04,  2.28629773e-03,
#         6.44641987e-04,  6.98193733e-04,  6.96313917e-04,  7.22461962e-04,
#         1.22615229e-03,  1.22965605e-03, -8.18365370e-04, -3.18663342e-06,
#         2.51836434e-04, -1.28957661e-04, -1.10305424e-04, -8.52674129e-04],
#       dtype=float32)]
# [array([[[[-0.03713588,  0.03392668,  0.05664402, ...,  0.033696  ,
#            0.05246336,  0.05631184],
#          [ 0.02614267, -0.0351937 ,  0.01215281, ..., -0.05256102,
#            0.00943495,  0.05499654],
#          [-0.00617975, -0.01585069,  0.0543703 , ...,  0.0078205 ,
#           -0.02020439, -0.05390875],
#          ...,
#          [ 0.04752088, -0.00087186,  0.05879518, ...,  0.00903036,
#            0.04597001,  0.02413139],
#          [ 0.03363702, -0.03116996, -0.00576457, ..., -0.01831951,
#           -0.05727011, -0.01655747],
#          [-0.03755759, -0.0467497 ,  0.04126697, ..., -0.04898502,
#            0.05089801,  0.01749506]],
#
#         [[ 0.04990456, -0.02355938, -0.00431155, ..., -0.02954872,
#           -0.00628593, -0.05031085],
#          [-0.00771661, -0.0513149 ,  0.05375626, ..., -0.00364605,
#            0.04242203, -0.04214721],
#          [ 0.01300306,  0.01474701,  0.00713457, ..., -0.0067809 ,
#           -0.06527071, -0.04044823],
#          ...,
#          [-0.06135358, -0.04633953,  0.06397729, ..., -0.00602047,
#           -0.0660818 , -0.01823855],
#          [-0.02121411,  0.01664951, -0.06483214, ...,  0.0205604 ,
#           -0.04612199, -0.04984556],
#          [-0.04314245, -0.0593539 ,  0.04483512, ..., -0.03770532,
#            0.04171837, -0.06352533]],
#
#         [[ 0.02985324, -0.06108821,  0.01811675, ..., -0.01268169,
#           -0.02819544, -0.04561207],
#          [-0.05677238, -0.00076447,  0.04939781, ..., -0.01194506,
#            0.00105543,  0.00838005],
#          [ 0.01938972, -0.04663798,  0.04862351, ..., -0.0244641 ,
#            0.06081191, -0.01785082],
#          ...,
#          [ 0.03407961, -0.05450685,  0.00029589, ..., -0.00109907,
#           -0.01693666,  0.00152864],
#          [-0.06420501, -0.06510637,  0.00837159, ...,  0.03917797,
#            0.0145308 , -0.01112991],
#          [-0.04996247,  0.06192349,  0.06375324, ..., -0.02948632,
#           -0.00830639, -0.05193646]],
#
#         ...,
#
#         [[-0.02426131,  0.04527932,  0.03544217, ..., -0.00971823,
#            0.02531327, -0.00967158],
#          [-0.06406169,  0.03985425,  0.05152707, ...,  0.00228664,
#            0.00986657, -0.02099344],
#          [-0.0329763 ,  0.02388746,  0.05413505, ..., -0.01645487,
#           -0.02882022, -0.02484954],
#          ...,
#          [-0.02566087,  0.03374581, -0.06447586, ..., -0.02868547,
#           -0.03408446,  0.05898103],
#          [-0.01051457, -0.06252466,  0.06726906, ..., -0.01967689,
#            0.01554634,  0.06079198],
#          [ 0.00283874,  0.02270648,  0.05425092, ...,  0.00355631,
#            0.02007999, -0.03536847]],
#
#        -1.04418409e-03,  2.49609846e-04, -9.46604414e-04, -1.32951920e-03,
#        -8.12620390e-04, -3.92411748e-04, -9.75360803e-04, -6.34746801e-04,
#        -1.64801790e-03, -4.62321768e-04,  1.44395512e-04, -3.60473059e-04,
#        -9.09575319e-05, -1.56862335e-03, -2.84034817e-04, -1.24944339e-03,
#        -6.26342022e-04, -9.52611212e-04, -2.27214914e-04, -6.72240159e-04,
#         4.96298890e-04,  2.11868028e-05, -4.03557468e-04, -5.65126829e-04,
#        -3.05121968e-04, -8.14560335e-04, -1.18333381e-03, -1.51671155e-03,
#        -1.45750097e-03, -9.87181324e-04, -6.14838558e-04,  7.55966466e-04,
#        -1.27048907e-03, -6.52311253e-04, -7.52450724e-04, -6.13443728e-04,
#        -3.49899434e-04, -9.96336807e-04, -2.04059086e-03, -8.84757144e-04,
#        -1.05410488e-03, -7.82361778e-04, -7.43290235e-04,  1.04135186e-04,
#         1.15050643e-04, -8.86085851e-04, -2.04502983e-04, -1.34641689e-03,
#        -1.05398220e-04, -1.99674559e-03, -9.94482707e-06, -4.26696584e-04,
#         2.44682979e-05, -1.55481073e-04, -1.20965112e-03, -1.15768472e-03,
#        -2.52337428e-04, -5.43611299e-04, -7.18547730e-04, -9.08175600e-04,
#        -4.11541492e-04, -4.44741658e-04, -8.00413836e-04,  3.32275667e-04,
#        -9.02826316e-04, -1.37317146e-03, -1.57472026e-03, -5.83648391e-04,
#        -6.66844717e-05, -6.77484641e-05, -2.63316615e-04, -3.84561135e-04,
#        -6.48461748e-04, -4.15335642e-04, -7.85788463e-04,  5.06595934e-05,
#        -1.74736604e-03, -1.28925210e-04, -1.50027359e-03,  4.20189346e-04,
#        -1.19872554e-03, -2.99867970e-04, -5.45253861e-04, -3.27359681e-04,
#        -1.23450591e-03, -1.97255472e-03, -1.10844756e-03, -6.12647098e-04,
#        -1.23805169e-03, -2.43172821e-04, -1.16580795e-03, -7.43608864e-04,
#        -1.10745372e-04, -6.45244087e-04, -1.03952200e-03, -4.65271063e-04,
#        -9.85122286e-04, -3.27407615e-04, -7.22414232e-04, -3.03692068e-04,
#        -1.63780618e-03, -2.57986307e-04,  4.94163396e-05,  1.09406392e-04,
#         2.63972761e-04, -1.00098411e-03,  2.07763136e-04, -4.12069669e-04,
#         1.34383317e-03, -7.34380854e-04, -6.48262794e-04, -7.29869062e-04,
#        -5.68168703e-04, -1.72496575e-03, -9.37122037e-04, -1.11071696e-03,
#        -1.08603260e-03, -9.93764261e-04, -1.61856343e-03, -3.34692013e-04],
#       dtype=float32)]
# []
# []
# []
# []
# []
# [array([[-0.01135642, -0.01264985,  0.00470412, ..., -0.00260847,
#          0.0109698 , -0.00432414],
#        [ 0.00792098, -0.00765541, -0.00314235, ...,  0.00102207,
#          0.00507939, -0.0031048 ],
#        [-0.01118043, -0.00467318, -0.0043717 , ..., -0.01176303,
#         -0.01025698, -0.00522404],
#        ...,
#        [ 0.0123763 ,  0.00615044, -0.00063597, ...,  0.00873875,
#         -0.00773766,  0.00054541],
#        [ 0.00317988,  0.00948307,  0.00665367, ..., -0.01133206,
#          0.00772242,  0.01010532],
#        [ 0.00694496, -0.00404976, -0.00102197, ..., -0.00242745,
#          0.00571983,  0.00175352]], dtype=float32), array([ 0.00014479, -0.00041788, -0.0001279 , ..., -0.00032794,
#         0.00018564, -0.00029666], dtype=float32)]
# []
# [array([[-0.00164836,  0.0148119 ,  0.01271117, ..., -0.03543172,
#         -0.01288766,  0.01503828],
#        [ 0.01851859, -0.01209157, -0.01980452, ...,  0.02258316,
#          0.01362178,  0.01833824],
#        [-0.01692386, -0.01392462, -0.03392497, ...,  0.03545622,
#          0.00706699,  0.00843951],
#        ...,
#        [-0.0182608 ,  0.01361797, -0.03830715, ...,  0.00204561,
#          0.03133551, -0.02173951],
#        [ 0.01274978,  0.02479892, -0.03569312, ...,  0.01726016,
#         -0.00689093,  0.00368954],
#        [-0.02889537, -0.00964058, -0.02972067, ..., -0.03520636,
#          0.00733748,  0.02941379]], dtype=float32), array([-1.54956477e-04, -5.11165817e-05,  2.02816751e-04,  1.16294987e-05,
#         3.73721086e-05,  1.13632857e-04,  2.48127762e-05, -3.89708621e-05,
#        -1.67835733e-05, -2.49410641e-06, -7.55288493e-05,  1.36953822e-04,
#         1.03005186e-05,  1.92311578e-04, -1.83131735e-04,  5.05758253e-05,
#         9.73734495e-05, -1.20762481e-04,  9.19098602e-05, -1.67210819e-05,
#         1.11842173e-05,  1.05108047e-04, -2.03566218e-04, -1.57803457e-04,
#        -2.69048847e-04, -4.39814503e-05,  2.11329796e-04,  2.23583629e-04,
#         2.67766063e-05,  2.37515123e-04,  2.68345884e-05,  5.52657148e-05,
#         8.65859693e-05, -5.06267897e-05,  9.85947045e-05,  2.07621459e-04,
#         4.08707929e-05,  2.87664210e-04,  5.92850374e-05, -4.15553914e-05,
#         3.26974114e-05, -1.05216401e-04,  2.09853984e-04,  4.70851301e-05,
#         1.74373090e-05,  2.31641709e-04, -1.34387243e-04, -8.50947890e-06,
#        -8.45031827e-05, -1.43894678e-04, -3.26661939e-05,  1.37648676e-04,
#        -3.64467240e-04, -1.84993565e-04, -1.64580939e-04,  1.95139175e-04,
#         1.55141242e-04,  6.60986334e-05,  5.33465864e-05,  3.81166356e-05,
#        -6.06365094e-04, -1.73633016e-04, -2.32831924e-04, -1.49714679e-05,
#        -4.73893306e-05,  1.83524011e-04,  1.38450210e-04, -4.50332227e-05,
#        -2.83378060e-04, -4.66036327e-05, -1.55754722e-04, -1.82739954e-04,
#         2.79317937e-05,  2.78114767e-05,  3.74175797e-05, -2.61438690e-04,
#        -8.46130933e-05,  1.29551583e-04,  3.42907151e-05, -1.39397933e-04,
#         1.78735863e-04,  2.33742030e-04, -7.79923939e-05, -2.87203642e-04,
#         4.56512025e-05,  5.50461809e-05,  5.35508152e-05,  1.23000704e-04,
#         3.13449389e-04,  4.75047200e-05,  2.20389644e-04, -3.38918326e-05,
#        -9.25429049e-05,  5.47656091e-05, -1.79275245e-04, -1.19398246e-04,
#        -4.88777914e-05,  2.33860439e-04,  1.80921896e-04,  7.94788230e-06],
#       dtype=float32)]
