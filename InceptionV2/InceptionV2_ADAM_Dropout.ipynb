# %%
#importing required libraries
from keras.datasets import cifar100
from tensorflow import keras
import keras, os
import numpy as np
import tensorflow as tf
from keras.datasets import cifar100
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, AvgPool2D, concatenate
from keras.layers import Conv2D, MaxPool2D, BatchNormalization, Input, Softmax
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import optimizers
from keras.metrics import Precision, Recall
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras import backend as K
from keras import regularizers
from keras.optimizers import Adam

# %%
train=True
num_classes = 100
reduction_factor = 8

(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train/ 255.0
x_test = x_test/ 255.0

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 4s 0us/step

# %%
def InceptionA(model):
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 32, kernel_size = (3,3), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 48, kernel_size = (3,3), strides = 1, padding ='same' )(model)
  # model = BatchNormalization()(model)
  # model = Dropout(0.1)(model)
  maxpool_2 = MaxPool2D(pool_size = (3,3), strides = 1, padding = 'same')(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 1, padding = 'same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)

  model = concatenate([maxpool_2, model], axis = -1)
  return model

# %%
def InceptionB(model):
  model = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,7), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (7,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,7), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (7,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,7), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (7,1), strides = 1, padding ='same'  )(model)
  # model = BatchNormalization()(model)
  # model = Dropout(0.1)(model)
  # model = keras.layers.Leakyelu()(model)
  maxpool_3 = MaxPool2D(pool_size =(3,3), strides = 1, padding = 'same')(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)

  model = concatenate([maxpool_3, model], axis = -1)
  return model

# %%
def InceptionC(model):
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,3), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (3,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,3), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (3,1), strides = 1, padding ='same'  )(model)
  # model = BatchNormalization()(model)
  # model = Dropout(0.1)(model)
  # model = keras.layers.Leakyelu()(model)
  maxpool_4 = MaxPool2D(pool_size =(3,3), strides = 1, padding = 'same')(model)
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  # model = Dropout(0.1)(model)
  model = Conv2D(filters = 256, kernel_size = (1,1), strides = 1, padding ='same' )(model)
  model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)

  model = concatenate([maxpool_4, model], axis = -1)
  return model

# %%
def Inception_reduction_1(model):
  model = Conv2D(filters = 32, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 64, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)
  maxpool_5 = MaxPool2D(3, strides = 2, padding = 'same')(model)

  model = concatenate([maxpool_5, model], axis = -1)
  return model

# %%
def Inception_reduction_2(model):
  model = Conv2D(filters = 128, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (3,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,3), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
  model = Conv2D(filters = 128, kernel_size = (1,1), strides = 1, padding ='same'  )(model)
  # model = Dropout(0.1)(model)
  # model = BatchNormalization()(model)
  model = keras.layers.LeakyReLU()(model)
  maxpool_6 = MaxPool2D(3, strides = 2, padding = 'same')(model)

  model = concatenate([maxpool_6, model], axis = -1)
  return model

# %%
x_shape = keras.Input((32, 32, 3))

num_inceptionA = 2
num_inceptionB = 3
num_inceptionC = 1

model = Conv2D(filters = 32, kernel_size = (3,3), strides = 2, padding ='same'  )(x_shape)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 32, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 64, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
# model = BatchNormalization()(model)
model = keras.layers.LeakyReLU()(model)
model = Dropout(0.1)(model)
maxpool_1 = MaxPool2D(pool_size = (3,3), strides = 2)(model)

model = Conv2D(filters = 64, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 128, kernel_size = (3,3), strides = 2, padding ='same'  )(model)
# model = BatchNormalization()(model)
# model = Dropout(0.1)(model)
model = Conv2D(filters = 128, kernel_size = (3,3), strides = 1, padding ='same'  )(model)
model = Dropout(0.1)(model)
model = keras.layers.LeakyReLU()(model)

for i in range(num_inceptionA):
  model = InceptionA(model)

# model = Inception_reduction_1(model)

for i in range(num_inceptionB):
  model = InceptionB(model)

# model = Inception_reduction_2(model)

for i in range(num_inceptionC):
  model = InceptionC(model)

avgpool = AvgPool2D(pool_size = (1,1))(model)
# Connected Layers
flatten = Flatten()(avgpool)
dense = Dense(4096)(flatten)
dense_act = keras.layers.LeakyReLU()(dense)
# model = Dropout(0.4)(model)
dense100 = Dense(100, activation = 'softmax')(dense_act)

# Create model
model1 = keras.Model(x_shape, dense100)
model1.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   18496       conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 16, 16, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 64)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 128)    73856       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 8, 8, 128)    0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 32)     4128        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 32)     1056        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 32)     9248        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 32)     1056        conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 48)     13872       conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 64)     27712       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 64)     4160        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 64)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 48)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 8, 8, 64)     0           dropout_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 112)    0           max_pooling2d_1[0][0]
#                                                                  leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 32)     3616        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 32)     1056        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 32)     9248        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 32)     1056        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 48)     13872       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     27712       conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     4160        conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 64)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 48)     0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 8, 8, 64)     0           dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 112)    0           max_pooling2d_2[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     7232        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 128)    57472       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 128)    0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 8, 128)    0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 256)    0           max_pooling2d_3[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 128)    57472       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_38[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 128)    0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 8, 8, 128)    0           dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 256)    0           max_pooling2d_4[0][0]
#                                                                  leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 64)     16448       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 128)    57472       conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    114816      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 8, 8, 128)    16512       conv2d_48[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 128)    0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 8, 8, 128)    0           dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 256)    0           max_pooling2d_5[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 8, 8, 256)    65792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 8, 8, 256)    65792       conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 8, 8, 256)    196864      conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 256)    65792       conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 256)    65792       conv2d_57[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8, 8, 256)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 256)    0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 256)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 512)    0           max_pooling2d_6[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 8, 8, 512)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32768)        0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4096)         134221824   flatten[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 4096)         0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          409700      leaky_re_lu_8[0][0]
# ==================================================================================================
# Total params: 138,764,580
# Trainable params: 138,764,580
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt = Adam(lr=0.00001)
model1.compile(optimizer=opt,
                loss='categorical_crossentropy',
                metrics=['accuracy', 'Precision', 'Recall'])

# %%
batch_size = 128

checkpoint = ModelCheckpoint("InceptionV2_Adam_dropout", monitor='val_accuracy', verbose=2, save_best_only=True, save_weights_only=True, mode='auto')
early = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=40, verbose=2, mode='auto')


# datagen = ImageDataGenerator(width_shift_range = 0.1,
#                              height_shift_range = 0.1,
#                              rotation_range = 10,
#                              horizontal_flip = True,
#                              vertical_flip = False,
#                              fill_mode = 'nearest')
# datagen = ImageDataGenerator()
# datagen.fit(x_train)

hist = model1.fit(x_train, y_train,
                    steps_per_epoch=x_train.shape[0]//batch_size,
                    epochs=100,
                    validation_data=(x_test, y_test),callbacks=[checkpoint, early],verbose=2)
# hist = model1.fit_generator(datagen.flow(x_train, y_train,
#                                  batch_size=batch_size),
#                     steps_per_epoch=x_train.shape[0]//batch_size,
#                     epochs=100,
#                     validation_data=(x_test, y_test),callbacks=[checkpoint, early],verbose=2)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.06250, saving model to InceptionV2_Adam_dropout
# 390/390 - 64s - loss: 4.3290 - accuracy: 0.0367 - precision: 0.2609 - recall: 2.3877e-04 - val_loss: 4.1359 - val_accuracy: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.06250 to 0.08940, saving model to InceptionV2_Adam_dropout
# 390/390 - 64s - loss: 4.0003 - accuracy: 0.0806 - precision: 0.4104 - recall: 0.0014 - val_loss: 3.9241 - val_accuracy: 0.0894 - val_precision: 0.5200 - val_recall: 0.0013
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.08940 to 0.09930, saving model to InceptionV2_Adam_dropout
# 390/390 - 69s - loss: 3.8763 - accuracy: 0.0969 - precision: 0.4780 - recall: 0.0030 - val_loss: 3.8615 - val_accuracy: 0.0993 - val_precision: 0.4706 - val_recall: 0.0056
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.09930 to 0.12450, saving model to InceptionV2_Adam_dropout
# 390/390 - 66s - loss: 3.7844 - accuracy: 0.1118 - precision: 0.5210 - recall: 0.0052 - val_loss: 3.7450 - val_accuracy: 0.1245 - val_precision: 0.4483 - val_recall: 0.0078
# Epoch 5/100
#
# Epoch 00005: val_accuracy improved from 0.12450 to 0.14340, saving model to InceptionV2_Adam_dropout
# 390/390 - 70s - loss: 3.6915 - accuracy: 0.1290 - precision: 0.5288 - recall: 0.0088 - val_loss: 3.6711 - val_accuracy: 0.1434 - val_precision: 0.5308 - val_recall: 0.0138
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.14340 to 0.15590, saving model to InceptionV2_Adam_dropout
# 390/390 - 70s - loss: 3.6101 - accuracy: 0.1432 - precision: 0.5637 - recall: 0.0119 - val_loss: 3.5735 - val_accuracy: 0.1559 - val_precision: 0.5816 - val_recall: 0.0196
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.15590 to 0.16750, saving model to InceptionV2_Adam_dropout
# 390/390 - 69s - loss: 3.5218 - accuracy: 0.1593 - precision: 0.5856 - recall: 0.0178 - val_loss: 3.5009 - val_accuracy: 0.1675 - val_precision: 0.5685 - val_recall: 0.0278
# Epoch 8/100
#
# Epoch 00008: val_accuracy improved from 0.16750 to 0.18400, saving model to InceptionV2_Adam_dropout
# 390/390 - 66s - loss: 3.4378 - accuracy: 0.1758 - precision: 0.6254 - recall: 0.0240 - val_loss: 3.4444 - val_accuracy: 0.1840 - val_precision: 0.5977 - val_recall: 0.0364
# Epoch 9/100
#
# Epoch 00009: val_accuracy improved from 0.18400 to 0.19180, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 3.3744 - accuracy: 0.1852 - precision: 0.6133 - recall: 0.0286 - val_loss: 3.3864 - val_accuracy: 0.1918 - val_precision: 0.6072 - val_recall: 0.0371
# Epoch 10/100
#
# Epoch 00010: val_accuracy improved from 0.19180 to 0.19620, saving model to InceptionV2_Adam_dropout
# 390/390 - 70s - loss: 3.3079 - accuracy: 0.1970 - precision: 0.6256 - recall: 0.0347 - val_loss: 3.3443 - val_accuracy: 0.1962 - val_precision: 0.5774 - val_recall: 0.0399
# Epoch 11/100
#
# Epoch 00011: val_accuracy improved from 0.19620 to 0.20970, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 3.2499 - accuracy: 0.2090 - precision: 0.6291 - recall: 0.0409 - val_loss: 3.2943 - val_accuracy: 0.2097 - val_precision: 0.6588 - val_recall: 0.0475
# Epoch 12/100
#
# Epoch 00012: val_accuracy improved from 0.20970 to 0.21110, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 3.1987 - accuracy: 0.2177 - precision: 0.6390 - recall: 0.0459 - val_loss: 3.2955 - val_accuracy: 0.2111 - val_precision: 0.5784 - val_recall: 0.0557
# Epoch 13/100
#
# Epoch 00013: val_accuracy improved from 0.21110 to 0.22510, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 3.1533 - accuracy: 0.2247 - precision: 0.6455 - recall: 0.0515 - val_loss: 3.2150 - val_accuracy: 0.2251 - val_precision: 0.6476 - val_recall: 0.0590
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.22510 to 0.22570, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 3.1017 - accuracy: 0.2379 - precision: 0.6527 - recall: 0.0575 - val_loss: 3.2169 - val_accuracy: 0.2257 - val_precision: 0.6045 - val_recall: 0.0703
# Epoch 15/100
#
# Epoch 00015: val_accuracy improved from 0.22570 to 0.23680, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 3.0683 - accuracy: 0.2443 - precision: 0.6579 - recall: 0.0610 - val_loss: 3.1344 - val_accuracy: 0.2368 - val_precision: 0.6628 - val_recall: 0.0739
# Epoch 16/100
#
# Epoch 00016: val_accuracy improved from 0.23680 to 0.23970, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 3.0160 - accuracy: 0.2523 - precision: 0.6693 - recall: 0.0687 - val_loss: 3.1143 - val_accuracy: 0.2397 - val_precision: 0.6421 - val_recall: 0.0775
# Epoch 17/100
#
# Epoch 00017: val_accuracy improved from 0.23970 to 0.24160, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 2.9830 - accuracy: 0.2600 - precision: 0.6731 - recall: 0.0726 - val_loss: 3.1193 - val_accuracy: 0.2416 - val_precision: 0.6340 - val_recall: 0.0764
# Epoch 18/100
#
# Epoch 00018: val_accuracy improved from 0.24160 to 0.24680, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 2.9425 - accuracy: 0.2670 - precision: 0.6777 - recall: 0.0782 - val_loss: 3.0857 - val_accuracy: 0.2468 - val_precision: 0.6531 - val_recall: 0.0864
# Epoch 19/100
#
# Epoch 00019: val_accuracy improved from 0.24680 to 0.26110, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 2.9039 - accuracy: 0.2717 - precision: 0.6715 - recall: 0.0832 - val_loss: 3.0415 - val_accuracy: 0.2611 - val_precision: 0.6801 - val_recall: 0.0948
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.26110
# 390/390 - 55s - loss: 2.8645 - accuracy: 0.2830 - precision: 0.6848 - recall: 0.0894 - val_loss: 3.0408 - val_accuracy: 0.2603 - val_precision: 0.6551 - val_recall: 0.0944
# Epoch 21/100
#
# Epoch 00021: val_accuracy improved from 0.26110 to 0.26660, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 2.8305 - accuracy: 0.2876 - precision: 0.6812 - recall: 0.0946 - val_loss: 3.0093 - val_accuracy: 0.2666 - val_precision: 0.6617 - val_recall: 0.0986
# Epoch 22/100
#
# Epoch 00022: val_accuracy did not improve from 0.26660
# 390/390 - 56s - loss: 2.7909 - accuracy: 0.2952 - precision: 0.6947 - recall: 0.1027 - val_loss: 3.0319 - val_accuracy: 0.2631 - val_precision: 0.6153 - val_recall: 0.1019
# Epoch 23/100
#
# Epoch 00023: val_accuracy did not improve from 0.26660
# 390/390 - 56s - loss: 2.7509 - accuracy: 0.3025 - precision: 0.6970 - recall: 0.1082 - val_loss: 3.0121 - val_accuracy: 0.2659 - val_precision: 0.6218 - val_recall: 0.1118
# Epoch 24/100
#
# Epoch 00024: val_accuracy improved from 0.26660 to 0.27590, saving model to InceptionV2_Adam_dropout
# 390/390 - 72s - loss: 2.7229 - accuracy: 0.3092 - precision: 0.6971 - recall: 0.1131 - val_loss: 2.9774 - val_accuracy: 0.2759 - val_precision: 0.6350 - val_recall: 0.1110
# Epoch 25/100
#
# Epoch 00025: val_accuracy improved from 0.27590 to 0.28410, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 2.6873 - accuracy: 0.3162 - precision: 0.7084 - recall: 0.1191 - val_loss: 2.9442 - val_accuracy: 0.2841 - val_precision: 0.6489 - val_recall: 0.1170
# Epoch 26/100
#
# Epoch 00026: val_accuracy improved from 0.28410 to 0.28420, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 2.6517 - accuracy: 0.3241 - precision: 0.6992 - recall: 0.1251 - val_loss: 2.9645 - val_accuracy: 0.2842 - val_precision: 0.6317 - val_recall: 0.1252
# Epoch 27/100
#
# Epoch 00027: val_accuracy improved from 0.28420 to 0.28570, saving model to InceptionV2_Adam_dropout
# 390/390 - 71s - loss: 2.6197 - accuracy: 0.3305 - precision: 0.7059 - recall: 0.1303 - val_loss: 2.9426 - val_accuracy: 0.2857 - val_precision: 0.6418 - val_recall: 0.1195
# Epoch 28/100
#
# Epoch 00028: val_accuracy improved from 0.28570 to 0.29580, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 2.5803 - accuracy: 0.3370 - precision: 0.7060 - recall: 0.1366 - val_loss: 2.9223 - val_accuracy: 0.2958 - val_precision: 0.6377 - val_recall: 0.1334
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.29580
# 390/390 - 55s - loss: 2.5498 - accuracy: 0.3451 - precision: 0.7062 - recall: 0.1426 - val_loss: 2.9187 - val_accuracy: 0.2958 - val_precision: 0.6075 - val_recall: 0.1370
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.29580
# 390/390 - 56s - loss: 2.5148 - accuracy: 0.3515 - precision: 0.7166 - recall: 0.1505 - val_loss: 2.9181 - val_accuracy: 0.2947 - val_precision: 0.6265 - val_recall: 0.1389
# Epoch 31/100
#
# Epoch 00031: val_accuracy improved from 0.29580 to 0.30000, saving model to InceptionV2_Adam_dropout
# 390/390 - 72s - loss: 2.4900 - accuracy: 0.3521 - precision: 0.7109 - recall: 0.1527 - val_loss: 2.9134 - val_accuracy: 0.3000 - val_precision: 0.6314 - val_recall: 0.1461
# Epoch 32/100
#
# Epoch 00032: val_accuracy improved from 0.30000 to 0.30240, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 2.4515 - accuracy: 0.3637 - precision: 0.7106 - recall: 0.1630 - val_loss: 2.9150 - val_accuracy: 0.3024 - val_precision: 0.6093 - val_recall: 0.1399
# Epoch 33/100
#
# Epoch 00033: val_accuracy improved from 0.30240 to 0.30330, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 2.4183 - accuracy: 0.3687 - precision: 0.7175 - recall: 0.1680 - val_loss: 2.9128 - val_accuracy: 0.3033 - val_precision: 0.6183 - val_recall: 0.1484
# Epoch 34/100
#
# Epoch 00034: val_accuracy improved from 0.30330 to 0.30980, saving model to InceptionV2_Adam_dropout
# 390/390 - 67s - loss: 2.3776 - accuracy: 0.3786 - precision: 0.7190 - recall: 0.1770 - val_loss: 2.8855 - val_accuracy: 0.3098 - val_precision: 0.6171 - val_recall: 0.1597
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.30980
# 390/390 - 55s - loss: 2.3401 - accuracy: 0.3851 - precision: 0.7217 - recall: 0.1862 - val_loss: 2.9109 - val_accuracy: 0.3058 - val_precision: 0.6086 - val_recall: 0.1563
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.30980
# 390/390 - 56s - loss: 2.3103 - accuracy: 0.3898 - precision: 0.7161 - recall: 0.1903 - val_loss: 2.9645 - val_accuracy: 0.2986 - val_precision: 0.5798 - val_recall: 0.1675
# Epoch 37/100
#
# Epoch 00037: val_accuracy improved from 0.30980 to 0.31540, saving model to InceptionV2_Adam_dropout
# 390/390 - 72s - loss: 2.2828 - accuracy: 0.3978 - precision: 0.7273 - recall: 0.1994 - val_loss: 2.9096 - val_accuracy: 0.3154 - val_precision: 0.6023 - val_recall: 0.1684
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.31540
# 390/390 - 56s - loss: 2.2366 - accuracy: 0.4074 - precision: 0.7289 - recall: 0.2071 - val_loss: 2.9167 - val_accuracy: 0.3031 - val_precision: 0.5813 - val_recall: 0.1687
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.31540
# 390/390 - 56s - loss: 2.2066 - accuracy: 0.4124 - precision: 0.7292 - recall: 0.2151 - val_loss: 2.9298 - val_accuracy: 0.3115 - val_precision: 0.5821 - val_recall: 0.1758
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.31540
# 390/390 - 57s - loss: 2.1691 - accuracy: 0.4214 - precision: 0.7273 - recall: 0.2250 - val_loss: 2.9434 - val_accuracy: 0.3085 - val_precision: 0.5790 - val_recall: 0.1822
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.31540
# 390/390 - 57s - loss: 2.1308 - accuracy: 0.4286 - precision: 0.7345 - recall: 0.2320 - val_loss: 2.9571 - val_accuracy: 0.3069 - val_precision: 0.5871 - val_recall: 0.1773
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.31540
# 390/390 - 57s - loss: 2.0908 - accuracy: 0.4365 - precision: 0.7388 - recall: 0.2430 - val_loss: 2.9538 - val_accuracy: 0.3108 - val_precision: 0.5791 - val_recall: 0.1834
# Epoch 43/100
#
# Epoch 00043: val_accuracy improved from 0.31540 to 0.31980, saving model to InceptionV2_Adam_dropout
# 390/390 - 69s - loss: 2.0553 - accuracy: 0.4439 - precision: 0.7380 - recall: 0.2502 - val_loss: 2.9869 - val_accuracy: 0.3198 - val_precision: 0.5548 - val_recall: 0.1922
# Epoch 44/100
#
# Epoch 00044: val_accuracy did not improve from 0.31980
# 390/390 - 56s - loss: 2.0198 - accuracy: 0.4569 - precision: 0.7439 - recall: 0.2620 - val_loss: 2.9792 - val_accuracy: 0.3185 - val_precision: 0.5601 - val_recall: 0.1999
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.31980
# 390/390 - 57s - loss: 1.9799 - accuracy: 0.4603 - precision: 0.7417 - recall: 0.2700 - val_loss: 3.0135 - val_accuracy: 0.3138 - val_precision: 0.5486 - val_recall: 0.2028
# Epoch 46/100
#
# Epoch 00046: val_accuracy did not improve from 0.31980
# 390/390 - 57s - loss: 1.9405 - accuracy: 0.4690 - precision: 0.7432 - recall: 0.2807 - val_loss: 2.9737 - val_accuracy: 0.3133 - val_precision: 0.5629 - val_recall: 0.1960
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.31980
# 390/390 - 57s - loss: 1.8851 - accuracy: 0.4852 - precision: 0.7489 - recall: 0.2956 - val_loss: 3.1000 - val_accuracy: 0.3145 - val_precision: 0.5227 - val_recall: 0.2104
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.31980
# 390/390 - 57s - loss: 1.8530 - accuracy: 0.4919 - precision: 0.7518 - recall: 0.3067 - val_loss: 3.0762 - val_accuracy: 0.3158 - val_precision: 0.5264 - val_recall: 0.2135
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.31980
# 390/390 - 57s - loss: 1.8242 - accuracy: 0.4967 - precision: 0.7534 - recall: 0.3130 - val_loss: 3.1085 - val_accuracy: 0.3111 - val_precision: 0.5213 - val_recall: 0.2149
# Epoch 50/100
#
# Epoch 00050: val_accuracy improved from 0.31980 to 0.32000, saving model to InceptionV2_Adam_dropout
# 390/390 - 68s - loss: 1.7603 - accuracy: 0.5110 - precision: 0.7588 - recall: 0.3320 - val_loss: 3.1069 - val_accuracy: 0.3200 - val_precision: 0.5296 - val_recall: 0.2218
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.32000
# 390/390 - 56s - loss: 1.7384 - accuracy: 0.5167 - precision: 0.7564 - recall: 0.3380 - val_loss: 3.1819 - val_accuracy: 0.3115 - val_precision: 0.5116 - val_recall: 0.2196
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.6753 - accuracy: 0.5325 - precision: 0.7625 - recall: 0.3549 - val_loss: 3.1965 - val_accuracy: 0.3155 - val_precision: 0.5051 - val_recall: 0.2239
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.6454 - accuracy: 0.5385 - precision: 0.7648 - recall: 0.3663 - val_loss: 3.2211 - val_accuracy: 0.3147 - val_precision: 0.5033 - val_recall: 0.2275
# Epoch 54/100
#
# Epoch 00054: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.5930 - accuracy: 0.5493 - precision: 0.7696 - recall: 0.3813 - val_loss: 3.2876 - val_accuracy: 0.3096 - val_precision: 0.4834 - val_recall: 0.2266
# Epoch 55/100
#
# Epoch 00055: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.5444 - accuracy: 0.5606 - precision: 0.7728 - recall: 0.3972 - val_loss: 3.3348 - val_accuracy: 0.3156 - val_precision: 0.4832 - val_recall: 0.2355
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.5120 - accuracy: 0.5680 - precision: 0.7737 - recall: 0.4095 - val_loss: 3.3661 - val_accuracy: 0.3134 - val_precision: 0.4751 - val_recall: 0.2339
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.4579 - accuracy: 0.5829 - precision: 0.7792 - recall: 0.4247 - val_loss: 3.4129 - val_accuracy: 0.3113 - val_precision: 0.4626 - val_recall: 0.2345
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.4198 - accuracy: 0.5886 - precision: 0.7824 - recall: 0.4387 - val_loss: 3.4493 - val_accuracy: 0.3105 - val_precision: 0.4630 - val_recall: 0.2371
# Epoch 59/100
#
# Epoch 00059: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.3662 - accuracy: 0.6035 - precision: 0.7885 - recall: 0.4555 - val_loss: 3.5278 - val_accuracy: 0.3073 - val_precision: 0.4454 - val_recall: 0.2365
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.3215 - accuracy: 0.6131 - precision: 0.7889 - recall: 0.4700 - val_loss: 3.5621 - val_accuracy: 0.3132 - val_precision: 0.4575 - val_recall: 0.2463
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.2832 - accuracy: 0.6242 - precision: 0.7921 - recall: 0.4870 - val_loss: 3.6043 - val_accuracy: 0.3090 - val_precision: 0.4419 - val_recall: 0.2424
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.2338 - accuracy: 0.6361 - precision: 0.7999 - recall: 0.5025 - val_loss: 3.6944 - val_accuracy: 0.3089 - val_precision: 0.4369 - val_recall: 0.2467
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.1842 - accuracy: 0.6505 - precision: 0.8032 - recall: 0.5207 - val_loss: 3.7943 - val_accuracy: 0.3023 - val_precision: 0.4144 - val_recall: 0.2429
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.1434 - accuracy: 0.6592 - precision: 0.8101 - recall: 0.5373 - val_loss: 3.8063 - val_accuracy: 0.3060 - val_precision: 0.4308 - val_recall: 0.2509
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.0925 - accuracy: 0.6736 - precision: 0.8140 - recall: 0.5540 - val_loss: 3.8802 - val_accuracy: 0.3074 - val_precision: 0.4137 - val_recall: 0.2533
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.0598 - accuracy: 0.6801 - precision: 0.8116 - recall: 0.5624 - val_loss: 3.9886 - val_accuracy: 0.3022 - val_precision: 0.4085 - val_recall: 0.2542
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 1.0145 - accuracy: 0.6945 - precision: 0.8212 - recall: 0.5849 - val_loss: 4.0171 - val_accuracy: 0.3078 - val_precision: 0.4106 - val_recall: 0.2601
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.9749 - accuracy: 0.7043 - precision: 0.8244 - recall: 0.5991 - val_loss: 4.0844 - val_accuracy: 0.3053 - val_precision: 0.4019 - val_recall: 0.2576
# Epoch 69/100
#
# Epoch 00069: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.9254 - accuracy: 0.7174 - precision: 0.8286 - recall: 0.6164 - val_loss: 4.2340 - val_accuracy: 0.3094 - val_precision: 0.3990 - val_recall: 0.2673
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.8999 - accuracy: 0.7261 - precision: 0.8329 - recall: 0.6294 - val_loss: 4.2077 - val_accuracy: 0.3085 - val_precision: 0.4001 - val_recall: 0.2642
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.8459 - accuracy: 0.7399 - precision: 0.8402 - recall: 0.6517 - val_loss: 4.2762 - val_accuracy: 0.3096 - val_precision: 0.3965 - val_recall: 0.2675
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.8115 - accuracy: 0.7496 - precision: 0.8444 - recall: 0.6637 - val_loss: 4.4524 - val_accuracy: 0.3070 - val_precision: 0.3881 - val_recall: 0.2697
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.7873 - accuracy: 0.7568 - precision: 0.8459 - recall: 0.6741 - val_loss: 4.5692 - val_accuracy: 0.3100 - val_precision: 0.3867 - val_recall: 0.2755
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.32000
# 390/390 - 57s - loss: 0.7567 - accuracy: 0.7672 - precision: 0.8487 - recall: 0.6878 - val_loss: 4.5709 - val_accuracy: 0.3045 - val_precision: 0.3798 - val_recall: 0.2687
# Epoch 00074: early stopping

# %%
model1.save_weights('InceptionV2_Adam_dropout.h5')

# %%
model1.load_weights(filepath = 'InceptionV2_Adam_dropout.h5')
scores = model1.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
print("Precison: %.2f%%" % (scores[2]*100))
print("Recall: %.2f%%" % (scores[3]*100))
# Out:
# Accuracy: 30.45%
# Precison: 37.98%
# Recall: 26.87%

# %%
# Plotting loss, accuracy, precision, recall
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['train','test'])
plt.title('loss')
plt.figure()
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.legend(['train','test'])
plt.title('accuracy')
plt.figure()
plt.plot(hist.history['precision'])
plt.plot(hist.history['val_precision'])
plt.legend(['train','test'])
plt.title('precision')
plt.figure()
plt.plot(hist.history['recall'])
plt.plot(hist.history['val_recall'])
plt.legend(['train','test'])
plt.title('recall')
# Out:
# Text(0.5, 1.0, 'recall')

# %%
# Printing saved weights in numpy arrays
for layer in model1.layers: 
  print(layer.get_weights())
